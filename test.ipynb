# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from dotenv import load_dotenv
import os

load_dotenv()

DATABASE_URL = "mysql+pymysql://admin:1234qwer@moonvie-database.ctimca2y05aw.ap-northeast-2.rds.amazonaws.com:3306/moonvieDB"
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

# %%
db = SessionLocal()

# %%
from sqlalchemy import text

# %%
query = db.execute(text("""select 
	movie_info.open_date,
    movie_statistics.audience_cnt,
    movie_statistics.sales_amount
from
    movie_statistics 
join
    movie_info on movie_statistics.movie_code = movie_info.movie_code
order by 
    movie_statistics.audience_cnt desc;"""))

# %%
query.fetchall()
# Out:
# [(datetime.date(2019, 4, 24), 3576049, 31286746070),
#  (datetime.date(2018, 4, 25), 3016632, 28695260709),
#  (datetime.date(2018, 4, 25), 3016632, 28695260709),
#  (datetime.date(2019, 5, 30), 2779579, 24041167435),
#  (datetime.date(2019, 12, 19), 2050297, 17512172960),
#  (datetime.date(2019, 12, 19), 2050297, 17512172960),
#  (datetime.date(2019, 3, 6), 1475589, 13004788110),
#  (datetime.date(2019, 3, 6), 1475589, 13004788110),
#  (datetime.date(2023, 3, 8), 1446131, 15030106566),
#  (datetime.date(2023, 3, 8), 1446131, 15030106566),
#  (datetime.date(2023, 12, 20), 1144823, 11435223289),
#  (datetime.date(2018, 10, 3), 959153, 8467611800),
#  (datetime.date(2018, 1, 11), 933349, 7330019142),
#  (datetime.date(2018, 1, 11), 933349, 7330019142),
#  (datetime.date(2019, 6, 20), 887127, 7468656800),
#  (datetime.date(2021, 7, 28), 870172, 8407456020),
#  (datetime.date(2022, 12, 21), 846294, 8529809459),
#  (datetime.date(2021, 11, 3), 787094, 8261476980),
# ...
